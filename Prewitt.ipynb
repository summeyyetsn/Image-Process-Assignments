# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('/media/sunflower.png')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#img_gaussian = cv2.GaussianBlur(gray,(3,3),0)

kernelx = np.array([[1,1,1],[0,0,0],[-1,-1,-1]])
kernely = np.array([[-1,0,1],[-1,0,1],[-1,0,1]])
#img_prewittx = cv2.filter2D(img_gaussian, -1, kernelx)
#img_prewitty = cv2.filter2D(img_gaussian, -1, kernely)

plt.subplot(2,2,1),plt.title('Original')
plt.imshow(gray, cmap = 'gray')

plt.subplot(2,2,2),plt.title('Prewitt')
plt.imshow( img_prewittx + img_prewitty ,cmap = 'gray')

plt.subplot(2,2,3),plt.title('Prewitt X')
plt.imshow( img_prewittx, cmap = 'gray')

plt.subplot(2,2,4),plt.title('Prewitt Y')
plt.imshow( img_prewitty, cmap = 'gray')




cv2.waitKey(0)
cv2.destroyAllWindows()
